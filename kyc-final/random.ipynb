# %%
import random
from faker import Faker

def generate_random_address():
    neighborhoods = ["Kebayoran Baru", "Kemang", "Menteng", "Senayan", "Kelapa Gading", "Cilandak"]
    cities = ["Jakarta Selatan", "Jakarta Pusat", "Jakarta Barat", "Jakarta Timur", "Jakarta Utara"]

    neighborhood = random.choice(neighborhoods)
    city = random.choice(cities)

    address = f"{neighborhood}, {city}"

    return address

def generate_random_religion():
    religions = ["Kristen", "Islam", "Budha", "Katolik", "Khonghucu", "Hindu"]
    religion = random.choice(religions)
    return religion

def generate_random_gender():
    genders = ["LAKI-LAKI", "PEREMPUAN"]
    gender = random.choice(genders)
    return gender

def generate_random_title():
    provinces = ["Aceh", "Bali", "Bangka Belitung", "Banten", "Bengkulu", "Gorontalo", "DKI Jakarta", "Jambi", "Jawa Barat",
                    "Jawa Tengah", "Jawa Timur", "Kalimantan Barat", "Kalimantan Selatan", "Kalimantan Tengah",
                    "Kalimantan Timur", "Kalimantan Utara", "Kepulauan Riau", "Lampung", "Maluku", "Maluku Utara",
                    "Nusa Tenggara Barat", "Nusa Tenggara Timur", "Papua", "Papua Barat", "Riau", "Sulawesi Barat",
                    "Sulawesi Selatan", "Sulawesi Tengah", "Sulawesi Tenggara", "Sulawesi Utara", "Sumatera Barat",
                    "Sumatera Selatan", "Sumatera Utara", "Yogyakarta"]

    cities = {
        "Aceh": ["Banda Aceh", "Langsa", "Lhokseumawe", "Meulaboh"],
        "Bali": ["Denpasar", "Singaraja", "Ubud"],
        "Bangka Belitung": ["Pangkal Pinang", "Tanjung Pandan"],
        "Banten": ["Serang", "Cilegon", "Tangerang"],
        "Bengkulu": ["Bengkulu", "Curup"],
        "Gorontalo": ["Gorontalo"],
        "DKI Jakarta": ["Jakarta Barat", "Jakarta Pusat", "Jakarta Selatan", "Jakarta Timur", "Jakarta Utara"],
        "Jambi": ["Jambi", "Muaro Jambi"],
        "Jawa Barat": ["Bandung", "Bekasi", "Bogor", "Cirebon", "Depok", "Sukabumi", "Tasikmalaya"],
        "Jawa Tengah": ["Semarang", "Surakarta", "Magelang", "Pekalongan"],
        "Jawa Timur": ["Surabaya", "Malang", "Sidoarjo", "Mojokerto"],
        "Kalimantan Barat": ["Pontianak", "Singkawang"],
        "Kalimantan Selatan": ["Banjarmasin", "Banjarbaru"],
        "Kalimantan Tengah": ["Palangka Raya"],
        "Kalimantan Timur": ["Samarinda", "Balikpapan"],
        "Kalimantan Utara": ["Tanjung Selor", "Tarakan"],
        "Kepulauan Riau": ["Tanjung Pinang", "Batam"],
        "Lampung": ["Bandar Lampung", "Metro"],
        "Maluku": ["Ambon", "Tual"],
        "Maluku Utara": ["Ternate", "Tidore"],
        "Nusa Tenggara Barat": ["Mataram", "Bima"],
        "Nusa Tenggara Timur": ["Kupang", "Ende"],
        "Papua": ["Jayapura", "Merauke"],
        "Papua Barat": ["Manokwari", "Sorong"],
        "Riau": ["Pekanbaru", "Dumai"],
        "Sulawesi Barat": ["Mamuju"],
        "Sulawesi Selatan": ["Makassar", "Palopo"],
        "Sulawesi Tengah": ["Palu"],
        "Sulawesi Tenggara": ["Kendari", "Baubau"],
        "Sulawesi Utara": ["Manado", "Bitung"],
        "Sumatera Barat": ["Padang", "Bukittinggi"],
        "Sumatera Selatan": ["Palembang", "Prabumulih"],
        "Sumatera Utara": ["Medan", "Binjai", "Pematangsiantar"],
        "Yogyakarta": ["Yogyakarta", "Sleman"]
    }

    province = random.choice(provinces)
    city = random.choice(cities[province])

    title1 = 'PROVINSI '+province
    title2 = city

    return title1.upper(), title2.upper()

def generate_random_indonesian_name():
    faker = Faker('id_ID')
    unique_name = faker.unique.name()
    return unique_name

def generate_random_nik():
    nik_digits = [str(random.randint(0, 9)) for _ in range(16)]
    nik = ''.join(nik_digits)
    return int(nik)

def generate_random_ktp_info():
    t = generate_random_title()
    print(t)


generate_random_ktp_info()
# Out:
# ('PROVINSI SULAWESI TENGAH', 'PALU')
