# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
txt = "The rain in Spain"

#Check if the string starts with "The":

x = re.findall("\AThe", txt)

print(x)

if x:
  print("Yes, there is a match!")
else:
  print("No match")
# Out:
# ['The']
# Yes, there is a match!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
txt = "The rain in Spain" # not match
# txt = "The ainbasdasd in Spain" # match

#Check if "ain" is present at the beginning of a WORD:

x = re.findall(r"\bain", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")

txt = "The rain in Spain"

#Check if "ain" is present at the end of a WORD:

x = re.findall(r"ain\b", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# []
# No match
# ['ain', 'ain']
# Yes, there is at least one match!

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
txt = "The rain in Spain"

#Check if "ain" is present, but NOT at the end of a word:

x = re.findall(r"ain\B", txt)

print(x)

if x:
  print("Yes, there is at least one match!")
else:
  print("No match")
# Out:
# []
# No match

# %%
txt = "aposdaokdsposakd asdposadkas adsa dad Tempat/Tgi Lahir asodiusaoidjaiosjodia"
txt_to_replace = "Tempat/Tgi Lahir"
x = re.sub(txt_to_replace, "Tempat/Tgl Lahir", txt)
print(x)
# Out:
# aposdaokdsposakd asdposadkas adsa dad Tempat/Tgl Lahir asodiusaoidjaiosjodia

# %%
class A:
    def __init__(self):
        self.makanan = "Ayam"

    def show_success(self,message):
        return self.makanan+" "+message + " victor"

a = A()
a.show_success("woi")
# Out:
# 'Ayam woi victor'
